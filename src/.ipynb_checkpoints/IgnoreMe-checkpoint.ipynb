# %%
import numpy as np
from Library import *
import json

# %%
dfDictist,indexes_names=load_indexes("../Data/indexes")
CapitalisationPath="../Data/cleanData/TestData.json"
dfs=comupte_etas(dfDictist,indexes_names)

# %%
index_names=indexes_names
etas=comupte_etas(dfDictist,index_names)
gamma=0.5
alpha=compute_alpha_matrix(CapitalisationPath,indexes_names,gamma)
beta=compute_beta_matrix(CapitalisationPath,indexes_names)
dates=list(etas.index)
P= pd.DataFrame(0, index=etas.index, columns=etas.columns)
R = pd.DataFrame(0, index=etas.index, columns=etas.columns)
Rcum = pd.DataFrame(0, index=etas.index, columns=etas.columns)
N=len(index_names)    
r_critic=100

# %%
R,cum=compute_Returns(dfDictist,indexes_names,r_critic,CapitalisationPath,indexes_names,gamma)

# %%
R["SSEC"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
R
# Out:
#                  SSEC       AEX        TWII       KS11        ATX        GDAX  \
# Date
# 2006-01-01   0.000000  0.000000    0.000000   0.000000   0.000000    0.000000
# 2006-01-02   0.000000  0.000000    0.000000   0.000000   0.000000    0.000000
# 2006-01-03   0.000000  2.970001    4.450196   5.950074  14.880127   39.739746
# 2006-01-04   0.000000  0.559998  115.569825   1.729980  35.629883    9.340332
# 2006-01-05  17.084961 -0.640015  -41.879883  -6.079956  43.250000   29.160156
# ...               ...       ...         ...        ...        ...         ...
# 2023-01-05   5.949952  7.549988   12.179688  50.000000  13.879883  223.799804
# 2023-01-06  22.459961 -1.599976   15.929688  -3.550049  28.949951  -14.920899
# 2023-01-08   2.569825  8.340027   94.820313  36.570069  29.530029  133.299804
# 2023-01-09   0.000000  0.000000    0.000000   0.000000   0.000000    0.000000
# 2023-01-10   6.709961  5.580017  247.740234  34.319824  -1.889893  142.099609
#
#             TA125_TA100        FCHI        JKSE      GSPTSE        N225  \
# Date
# 2006-01-01     0.000000    0.000000    0.000000    0.000000    0.000000
# 2006-01-02     0.000000    0.000000    0.000000    0.000000    0.000000
# 2006-01-03    19.489990   23.000000    9.731933    0.000000    0.000000
# 2006-01-04     2.630005   15.029785   14.660888  137.000000    0.000000
# 2006-01-05     6.369995   17.620118   19.266968   92.500000   66.889648
# ...                 ...         ...         ...         ...         ...
# 2023-01-05     1.209961  115.830078  -75.560058  128.701172 -118.070313
# 2023-01-06   -10.280030   17.000000 -159.438965  -11.898438   -4.699219
# 2023-01-08     0.000000   88.010254   30.798339  198.900391  233.769531
# 2023-01-09     6.189941    0.000000    0.000000    0.000000    0.000000
# 2023-01-10    12.829956   45.770019    3.707032  -42.900391    0.000000
#
#                    HSI        SSMI          MXX    BVSP
# Date
# 2006-01-01    0.000000    0.000000     0.000000     0.0
# 2006-01-02    0.000000    0.000000     0.000000     0.0
# 2006-01-03    0.000000    0.000000   122.988281    45.0
# 2006-01-04  100.799804    7.500000   575.240234  1034.0
# 2006-01-05   87.299804   32.700195   167.281250   462.0
# ...                ...         ...          ...     ...
# 2023-01-05  473.128906  119.529297  1147.960937  1167.0
# 2023-01-06 -243.699219  -36.220704   654.441407  2182.0
# 2023-01-08 -229.250000   75.919922   929.660156  1194.0
# 2023-01-09    0.000000    0.000000     0.000000     0.0
# 2023-01-10   92.400391   41.150391   509.949218   263.0
#
# [5292 rows x 15 columns]

# %% [markdown]
# $$P_i (t)=P_i(t-1) exp(R_i (t))$$
# $$R_i(t)=\frac{1}{N_i^*} \sum_{j \neq i}^N \alpha_{i j} \Theta\left(R_j^{c u m}(t-1)>R_C\right) \times R_j^{c u m}(t-1) \beta_{i j}+\eta_i(t), \quad (1)$$
# $$R_j^{c u m}(t)=\left(1-\Theta\left(R_j^{c u m}(t-1)>R_C\right)\right)\left[R_j^{c u m}(t-1)+R_j(t)\right] \qquad (2)$$
# $$N_i^*=\sum_{j \neq i}^N \Theta\left(R_j^{c u m}(t-1)>R_C\right), \alpha_{i j}=1-\exp \left\{-K_j /\left(K_i \gamma\right)\right\} \qquad (3)$$
# $$\beta_{i j}=\exp \left\{-\left(z_i-z_j\right) / \tau\right\}$$
# $$\alpha ( i,j) = 1 - \exp (-K_j /(K_i\gamma)),$$

# %%
sign=lambda x:1 if x
