# %%
import numpy as np
from Library import *
import json

# %%
dfDictist,indexes_names=load_indexes("../Data/indexes")

# %%
dfs=comupte_etas(dfDictist,indexes_names)

# %%
dfs['SSEC'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
d = pd.DataFrame(0, index=dfs.index, columns=dfs.columns)

# %%
Hievisied=lambda r,r_critic:1*(r>=r_critic)

# %%
r_critic=100

# %%
Hievisied(dfs['SSEC'],r_critic).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs['SSEC'].loc["2023-01-05"]
# Out:
# 22.45996100000002

# %%
dfs['SSEC'].loc["2023-01-05"]=0

# %%
dfs['SSEC']
# Out:
# Date
# 1990-01-01         NaN
# 1990-01-02         NaN
# 1990-01-03         NaN
# 1990-01-04         NaN
# 1990-01-05         NaN
#                 ...
# 2023-01-05    0.000000
# 2023-01-06    2.569825
# 2023-01-08         NaN
# 2023-01-09    6.709961
# 2023-01-10   -8.514893
# Name: SSEC, Length: 10157, dtype: float64

# %%
gamma=0.5
R=compute_Returns(dfDictist,indexes_names,r_critic,"../Data/cleanData/TestData.json",indexes_names,gamma)

# %%
R.columns
# Out:
# Index(['SSEC', 'AEX', 'TWII', 'KS11', 'ATX', 'GDAX', 'TA125_TA100', 'FCHI',
#        'JKSE', 'GSPTSE', 'N225', 'HSI', 'SSMI', 'MXX', 'BVSP'],
#       dtype='object')

# %%
R["N225"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
R["HSI"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
