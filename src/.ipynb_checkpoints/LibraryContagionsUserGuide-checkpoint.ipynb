# %%
import matplotlib.pyplot as plt
from Library import *

# %% [markdown]
# # Load indexes
# This function load indexes data as dictionary in whitch, keys are indexes names and values are dataframes that contain informations Date,open,close,Hight,Low,Close,Adj Close,Volume

# %%
dfDictist,indexes_names=load_indexes("../Data/indexes")
dfDictist["SSEC"].head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-07-02  1255.909058  1261.571045  1147.331055  1199.061035  1199.061035
# 1997-07-03  1194.676025  1194.676025  1149.939941  1150.623047  1150.623047
# 1997-07-04  1138.921021  1163.249023  1124.776001  1159.342041  1159.342041
# 1997-07-07  1161.707031  1163.447021  1085.572021  1096.818970  1096.818970
# 1997-07-08  1092.798950  1115.432983  1066.043945  1109.666016  1109.666016
#
#             Volume
# Date
# 1997-07-02     0.0
# 1997-07-03     0.0
# 1997-07-04     0.0
# 1997-07-07     0.0
# 1997-07-08     0.0

# %%
dfDictist["SSEC"]["Close"].values
# Out:
# array([1199.061035, 1150.623047, 1159.342041, ..., 3157.639893,
#        3176.080078, 3169.50708 ])

# %% [markdown]
# ### Plot with indexes of dates

# %%
fig=plt.figure(figsize=(20,8))
plt.plot(dfDictist["SSEC"]["Close"])
plt.plot(dfDictist["SSEC"]["Open"])

# %%
rate=dfDictist["SSEC"].Close/dfDictist["SSEC"].Open

# %%
rate.plot(figsize=(20,18))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig=plt.figure(figsize=(20,8))
dfDictist["SSEC"].plot(y=["Open", "Close","Adj Close"], figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
rate.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Compute beta
# we can compute beta matrix, by having a file that contain the timezone for each index, and a value of $\tau$

# %%
tho=3
beta=compute_beta_matrix("../Data/cleanData/TestData.json",indexes_names,tho)

# %%
beta[:3,:3]
# Out:
# array([[1.        , 0.36787944, 0.02556153],
#        [0.36787944, 1.        , 0.00940356],
#        [0.02556153, 0.00940356, 1.        ]])

# %% [markdown]
# # Compute Alpha
# we can compute alpha matrix, using a file that contain the capitalisation for each index, and a value of $\gamma$

# %%
gamma=0.5
#Unifrom Capitalisation
alpha=compute_alpha_matrix("../Data/cleanData/TestData.json",indexes_names,gamma)
print(alpha[:3,:3])
# Out:
# [[0.86466472 0.86466472 0.86466472]
#  [0.86466472 0.86466472 0.86466472]
#  [0.86466472 0.86466472 0.86466472]]

# %%
gamma=1
#Unifrom Capitalisation
alpha=compute_alpha_matrix("../Data/cleanData/TestData.json",indexes_names,gamma,"RandomCapitalisation")
print(alpha[:3,:3])
# Out:
# [[0.63212056 0.8111244  0.48658288]
#  [0.45118836 0.63212056 0.32967995]
#  [0.77686984 0.917915   0.63212056]]

# %% [markdown]
# # compute eta

# %%
etas=comupte_etas(dfDictist,indexes_names)

# %%
etas
# Out:
#                  SSEC       AEX        TWII       KS11        ATX        GDAX  \
# Date
# 1965-01-05        NaN       NaN         NaN        NaN        NaN         NaN
# 1965-01-06        NaN       NaN         NaN        NaN        NaN         NaN
# 1965-01-07        NaN       NaN         NaN        NaN        NaN         NaN
# 1965-01-08        NaN       NaN         NaN        NaN        NaN         NaN
# 1965-01-11        NaN       NaN         NaN        NaN        NaN         NaN
# ...               ...       ...         ...        ...        ...         ...
# 2023-01-05  22.459961 -1.599976   15.929688  -3.550049  28.949951  -14.920899
# 2023-01-06   2.569825  8.340027   94.820313  36.570069  29.530029  133.299804
# 2023-01-08        NaN       NaN         NaN        NaN        NaN         NaN
# 2023-01-09   6.709961  5.580017  247.740234  34.319824  -1.889893  142.099609
# 2023-01-10  -8.514893       NaN    6.690430   3.270020        NaN         NaN
#
# ...

# %%
etas["TA125_TA100"].plot(figsize=(20,18))
# Out:
# <AxesSubplot:xlabel='Date'>
